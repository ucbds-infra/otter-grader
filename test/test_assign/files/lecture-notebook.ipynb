# %% [raw]
# # ASSIGNMENT CONFIG
# init_cell: false
# export_cell: false
# strip_solutions_from_all_cells: true
# suppress_no_tests_warning: true
# generate: false

# %% [markdown]
# # A lecture notebook
#
# This cell is outside of a question

# %%
# so is this one
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# make some data

# %%
data = np.linspace(10, 20) # SOLUTION

# %% [markdown]
# make a chart

# %%
plt.scatter(range(len(data)), data)

# %% [raw]
# # BEGIN QUESTION
# name: q1
# manual: true

# %% [markdown]
# question 1

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# this is a solution cell that should be removed

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q2
# manual: true

# %% [markdown]
# question 2 with prompt

# %% [raw]
# # BEGIN PROMPT

# %% [markdown]
# this is a prompt cell

# %% [raw]
# # END PROMPT

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# this is a solution cell that should be removed

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION
